# %% [markdown]
# ## TFM. Paso 1 -  Concatenar Datasets

# %% [markdown]
# Ya que tenemos todos los datasets en archivos excels diferentes, lo primero que haremos será unirlos en un mismo dataframe. Para ello, utilizaremos una función que vaya recorriendo el path donde están guardados todos los archivos y uniéndolos con un concat.

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r"C:/Users/carlos.guisado/Documents/Thomson/Uipath/Descargas/Data/"
archivo = os.listdir(r"C:\Users\carlos.guisado\Documents\Thomson\Uipath\Descargas\Data")

# %%
print("Contamos con " + str(len(archivo)) + " datasets, que equivalen a los datos financieros de " + str(len(archivo)) + " empresas que cotizan en la bolsa americana.")
# Out:
# Contamos con 1166 datasets, que equivalen a los datos financieros de 1166 empresas que cotizan en la bolsa americana.

# %%
#Abrimos el primer excel de todos para comprobar que se ha cargado correctamente.
#Archivo Excel ajuntado en Github - df.xlsx
df = pd.read_excel(r"C:\Users\carlos.guisado\Documents\Thomson\Uipath\Descargas\Data\A.xlsx", sheet_name = "FinancialData")
df.head()
# Out:
#                    Company Name                   Country  \
# 0  Agilent Technologies Inc (A)  United States of America
# 1  Agilent Technologies Inc (A)  United States of America
# 2  Agilent Technologies Inc (A)  United States of America
# 3  Agilent Technologies Inc (A)  United States of America
# 4  Agilent Technologies Inc (A)  United States of America
#
#                TRBC Industry Group Reporting Unit  Field Name  Mkt Cap Var  \
# 0  Healthcare Equipment & Supplies       Millions  31-10-2019          NaN
# 1  Healthcare Equipment & Supplies       Millions  31-10-2018     0.135045
# 2  Healthcare Equipment & Supplies       Millions  31-10-2017    -0.056677
# 3  Healthcare Equipment & Supplies       Millions  31-10-2016     0.549089
# 4  Healthcare Equipment & Supplies       Millions  31-10-2015     0.129429
#
#    Market Capitalization  Tot Rev from Biz Activ  \
# 0               23442.18                    5163
# 1               20653.08                    4914
# 2               21893.96                    4472
# 3               14133.44                    4202
# 4               12513.79                    4038
#
#    Gross Profit - Ind/Prop - Tot  Op Profit Bef Non-Recur Inc/(Expn)  ...  \
# 0                           2813                                 997  ...
# 1                           2684                                 933  ...
# 2                           2398                                 818  ...
# 3                           2200                                 656  ...
# 4                           2023                                 568  ...
#
#    PE Growth Ratio  PE Growth Ratio, 5 Yr Avg  Enterprise Value To Tot Rev  \
# 0             0.86                       0.71                         4.74
# 1             0.89                       0.95                         4.11
# 2             0.66                      -4.32                         4.75
# 3             4.19                      -1.89                         3.27
# 4             0.32                      -2.50                         3.01
#
#    Enterprise Value To Tot Rev, 5 Yr Avg  Enterprise Value To EBITDA  \
# 0                                   4.03                       19.80
# 1                                   3.93                       17.65
# 2                                   3.96                       20.57
# 3                                   3.18                       15.23
# 4                                   2.79                       14.80
#
#    Enterprise Value To EBITDA, 5 Yr Avg  \
# 0                                 17.87
# 1                                 17.93
# 2                                 18.65
# 3                                 15.30
# 4                                 13.63
#
#    Enterprise Value To Net Cash Flow From Op  \
# 0                                      23.96
# 1                                      18.59
# 2                                      23.88
# 3                                      17.34
# 4                                      23.77
#
#    Enterprise Value To Net Cash Flow From Op, 5 Yr Avg  \
# 0                                              21.35
# 1                                              21.35
# 2                                              20.18
# 3                                              16.65
# 4                                              14.59
#
#    Enterprise Value To FOCF  Enterprise Value To FOCF, 5 Yr Avg
# 0                     37.13                               33.93
# 1                     28.11                               35.86
# 2                     39.10                               33.29
# 3                     27.28                               25.72
# 4                     43.31                               20.79
#
# [5 rows x 112 columns]

# %%
#Añadimos, utilizando un 'concat', los datos de las demás empresas que queremos analizar, con el 
#objetivo de crear un dataset con todas las empresas y datos financieros.
for i in range (1,len(archivo)):
    file = path + archivo[i]
    temp_data = pd.read_excel(file, sheet_name = "FinancialData")
    df = pd.concat([df, temp_data], axis = 0, ignore_index = True, verify_integrity = True)
df = df.dropna(axis = 1, how = 'all')
df
# Out:
#                        Company Name                   Country  \
# 0      Agilent Technologies Inc (A)  United States of America
# 1      Agilent Technologies Inc (A)  United States of America
# 2      Agilent Technologies Inc (A)  United States of America
# 3      Agilent Technologies Inc (A)  United States of America
# 4      Agilent Technologies Inc (A)  United States of America
# ...                             ...                       ...
# 14007              Zoetis Inc (ZTS)  United States of America
# 14008              Zoetis Inc (ZTS)  United States of America
# 14009              Zoetis Inc (ZTS)  United States of America
# 14010              Zoetis Inc (ZTS)  United States of America
# 14011              Zoetis Inc (ZTS)  United States of America
#
#                    TRBC Industry Group Reporting Unit  Field Name  \
# 0      Healthcare Equipment & Supplies       Millions  31-10-2019
# 1      Healthcare Equipment & Supplies       Millions  31-10-2018
# 2      Healthcare Equipment & Supplies       Millions  31-10-2017
# 3      Healthcare Equipment & Supplies       Millions  31-10-2016
# 4      Healthcare Equipment & Supplies       Millions  31-10-2015
# ...                                ...            ...         ...
# 14007                  Pharmaceuticals       Millions  31-12-2014
# 14008                  Pharmaceuticals       Millions  31-12-2013
# 14009                  Pharmaceuticals       Millions  31-12-2012
# 14010                  Pharmaceuticals       Millions  31-12-2011
# 14011                  Pharmaceuticals       Millions  31-12-2010
#
#        Mkt Cap Var  Market Capitalization  Tot Rev from Biz Activ  \
# 0              NaN               23442.18                  5163.0
# 1         0.135045               20653.08                  4914.0
# 2        -0.056677               21893.96                  4472.0
# 3         0.549089               14133.44                  4202.0
# 4         0.129429               12513.79                  4038.0
# ...            ...                    ...                     ...
# 14007     0.106079               21572.01                  4785.0
# 14008     0.319775               16345.22                  4561.0
# 14009          NaN                    NaN                  8672.0
# 14010          NaN                    NaN                  8466.0
# 14011          NaN                    NaN                  7164.0
#
#        Gross Profit - Ind/Prop - Tot  Op Profit Bef Non-Recur Inc/(Expn)  ...  \
# 0                             2813.0                               997.0  ...
# 1                             2684.0                               933.0  ...
# 2                             2398.0                               818.0  ...
# 3                             2200.0                               656.0  ...
# 4                             2023.0                               568.0  ...
# ...                              ...                                 ...  ...
# 14007                         3040.0                               998.0  ...
# 14008                         2856.0                               849.0  ...
# 14009                         7087.0                              5231.0  ...
# 14010                         6777.0                              4913.0  ...
# 14011                         5692.0                              3908.0  ...
#
#        Enterprise Value To Net Cash Flow From Op, 5 Yr Avg.1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14007                                                NaN
# 14008                                                NaN
# 14009                                                NaN
# 14010                                                NaN
# 14011                                                NaN
#
#        Enterprise Value To FOCF.1  Enterprise Value To FOCF, 5 Yr Avg.1  \
# 0                             NaN                                   NaN
# 1                             NaN                                   NaN
# 2                             NaN                                   NaN
# 3                             NaN                                   NaN
# 4                             NaN                                   NaN
# ...                           ...                                   ...
# 14007                         NaN                                   NaN
# 14008                         NaN                                   NaN
# 14009                         NaN                                   NaN
# 14010                         NaN                                   NaN
# 14011                         NaN                                   NaN
#
#        Div Yld - Com Stock - Issue, 3 Yr Avg.2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 14007                                      NaN
# 14008                                      NaN
# 14009                                      NaN
# 14010                                      NaN
# 14011                                      NaN
#
#        Div Yld - Com Stock - Issue, 3 Yr Avg.3  Non-GAAP Adj EBITDA.1  \
# 0                                          NaN                    NaN
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
# ...                                        ...                    ...
# 14007                                      NaN                    NaN
# 14008                                      NaN                    NaN
# 14009                                      NaN                    NaN
# 14010                                      NaN                    NaN
# 14011                                      NaN                    NaN
#
#        Non-GAAP Free Cash Flow.1  Net Stable Funding Ratio - Basel 3 - %  \
# 0                            NaN                                     NaN
# 1                            NaN                                     NaN
# 2                            NaN                                     NaN
# 3                            NaN                                     NaN
# 4                            NaN                                     NaN
# ...                          ...                                     ...
# 14007                        NaN                                     NaN
# 14008                        NaN                                     NaN
# 14009                        NaN                                     NaN
# 14010                        NaN                                     NaN
# 14011                        NaN                                     NaN
#
#        Div Yld - Com Stock - Issue, TTM.4  Div Yld - Com Stock - Issue, TTM.5
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
# ...                                   ...                                 ...
# 14007                                 NaN                                 NaN
# 14008                                 NaN                                 NaN
# 14009                                 NaN                                 NaN
# 14010                                 NaN                                 NaN
# 14011                                 NaN                                 NaN
#
# [14012 rows x 464 columns]

# %%
print("Tenemos un dataset compuesto por " + str(len(archivo)) + " empresas, con un shape = " + str(df.shape))
print("Esto se debe a que cada empresa, como hemos visto anteriormente al abrir el primero de los archivos, está compuesta por un historial variable de entre 1-10 años.")
print("Dependiendo de la industria, disponemos de unos datos financieros o de otros, por lo que el siguiente paso será la división por industria.")
# Out:
# Tenemos un dataset compuesto por 1166 empresas, con un shape = (14012, 464)
# Esto se debe a que cada empresa, como hemos visto anteriormente al abrir el primero de los archivos, está compuesta por un historial variable de entre 1-10 años.
# Dependiendo de la industria, disponemos de unos datos financieros o de otros, por lo que el siguiente paso será la división por industria.

# %%
df.to_excel('df.xlsx', header=True, index=False)
